# %% [markdown]
# *this is where i'll work on the data*

# %% [markdown]
# # 1) Clean & Tidy data
#
# This will take up the largest chunk of our time!

# %% [markdown]
# ## Load Data & Packages

# %% [markdown]
# First let's load in and look at our raw data:

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# load raw data (this is a version of survey when there were 30 responses, but the column names are the same as the version with 50 responses, so we can use this for testing our code before we run it on the full dataset)

csv_file = 'C:\\Users\\aranz\\OneDrive\\music_and_motivation\\music-motivation-survey-repo\\data\\raw\\survey_30_responses_(starter).csv'
survey_df = pd.read_csv(csv_file)

# view data
survey_df.head()
# Out:
#             Timestamp  Score  First and Last Name   Email  \
# 0  2/25/2026 12:10:43    NaN                   NaN    NaN
# 1  2/25/2026 12:19:46    NaN                   NaN    NaN
# 2  2/25/2026 12:21:41    NaN                   NaN    NaN
# 3  2/25/2026 12:32:51    NaN                   NaN    NaN
# 4  2/25/2026 12:38:44    NaN                   NaN    NaN
#
#    Do you believe yourself to be Introverted or Extroverted?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your gender identity?   \
# 0                           Male
# 1                         Female
# 2                        Female
# 3                        female
# 4                         Female
#
#    Which category best describes you? (select all that apply)   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your preferred music genre? (on a daily basis)   \
# 0                                    Electronic, Pop
# 1                                      Hip Hop & R&B
# 2                                 Hip Hop & R&B, Pop
# 3                                 Hip Hop & R&B, Pop
# 4                    Metal/ Rock, Hip Hop & R&B, Pop
#
#    On a scale of 1-5, how introverted are you?\n(1 = introverted, 5 = extroverted)  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  2
#
#    How old are you?   ...  \
# 0                 23  ...
# 1                 20  ...
# 2                 21  ...
# 3                 19  ...
# 4                 19  ...
#
#    When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?  \
# 0                  singing, ambience with good vibes
# 1  Something to pump up or fill in the lack of en...
# 2                              dancing and ambience
# 3                             reminiscing & singing
# 4  I think having a playlist that is fun, nostalg...
#
#                            Why do you go to parties?  \
# 0           To socialize with my friends and dance.
# 1  For free drinks foods or with my friends or to...
# 2  FOMO, friends are going and to take a break fr...
# 3                        make memories & to have fun
# 4  Just to be with friends who are there and for ...
#
#    What is/are your ethnicity/ies? What is/are your nationality/ ies?  \
# 0                           Latino                   Meixcan-American
# 1                       Vietnamese                           American
# 2                        Hispanic                           American
# 3              Chinese/Vietnamese                           American
# 4                       Vietnamese                           American
#
#    On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?\n(1 = very unlikely, 5 = very likely)  \
# 0                                                  2
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#   On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#   Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)  \
# 0                                  admontan@ucsd.edu
# 1                                                 No
# 2                                                N/a
# 3                                                 no
# 4                                       No thank you
#
#   Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!\n\n*Please specify song title and artist(s)!*  \
# 0  Bad Bunny - Baile Inolvidable, Karol G - Si An...
# 1  Any Daniel ceasar song, Melancholy Hill, Every...
# 2  never hosted before but would put Spanish regg...
# 3  lady killers, 3 strikes, girlfriend heavy weig...
# 4  I like all the stars by kendrick and sza, titi...
#
#    Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)  \
# 0  Yes I have. While I feel more shy sometimes, i...
# 1                                Yes, I laughed more
# 2  Yes, I tried drinking but I ended up throwing ...
# 3  yes it was chill everybody was already in a ha...
# 4                                                NaN
#
#   Column 12
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# There's a bunch of columns that we actually don't need because no data ended up being needed to be recorded from them so I'll get rid of those:

# %%
# see column names
survey_df.columns
# Out:
# Index(['Timestamp', 'Score', 'First and Last Name ', 'Email',
#        'Do you believe yourself to be Introverted or Extroverted?',
#        'What is your gender identity? ',
#        'Which category best describes you? (select all that apply) ',
#        'What is your preferred music genre? (on a daily basis) ',
#        'On a scale of 1-5, how introverted are you?\n(1 = introverted, 5 = extroverted)',
#        'How old are you? ', 'What is your college major? ', 'Email Address',
#        'On a daily basis, what is the language of music you listen to? ',
#        'What is your preferred music genre to listen to at parties? ',
#        'What are your top 5 Artists for going out? ',
#        'What are your top 5 songs before going out (this can be on your own or with others) (e.g., pregame, getting ready, etc.)? \n\n*Please specify song title and artist(s)!*',
#        'What do you like about the parties you have gone to so far? (music, environment, loudness, etc. ) ',
#        'What don't you like about parties? (music, environment, loudness, etc. ) ',
#        'On a scale of 1-5, how likely are you to pregame before a party/gathering?\n(1 = very unlikely, 5 = very likely)',
#        'How many times have you gone to a gathering in the last 2 months?',
#        'What emotions do you feel when listening to these top 5 songs?',
#        'On a scale of 1-5, how likely are you to come up to a stranger at a party sober? \n(1 = very unlikely, 5 = very likely)',
#        'On a scale of 1-5, how likely are you to sing along to a song at a party sober?\n(1 = very unlikely, 5 = very likely)',
#        'When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?',
#        'Why do you go to parties?', 'What is/are your ethnicity/ies?',
#        'What is/are your nationality/ ies?',
#        'On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?\n(1 = very unlikely, 5 = very likely)',
#        'On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?',
#        'Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)',
#        'Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!\n\n*Please specify song title and artist(s)!*',
#        'Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)',
#        'Column 12'],
#       dtype='object')

# %%
# removing columns that are not needed for analysis which are the ones with all missing values
survey_df = survey_df.dropna(axis=1, how='all')

survey_df.head()
# Out:
#             Timestamp What is your gender identity?   \
# 0  2/25/2026 12:10:43                           Male
# 1  2/25/2026 12:19:46                         Female
# 2  2/25/2026 12:21:41                        Female
# 3  2/25/2026 12:32:51                        female
# 4  2/25/2026 12:38:44                         Female
#
#   What is your preferred music genre? (on a daily basis)   \
# 0                                    Electronic, Pop
# 1                                      Hip Hop & R&B
# 2                                 Hip Hop & R&B, Pop
# 3                                 Hip Hop & R&B, Pop
# 4                    Metal/ Rock, Hip Hop & R&B, Pop
#
#    On a scale of 1-5, how introverted are you?\n(1 = introverted, 5 = extroverted)  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  2
#
#    How old are you?   \
# 0                 23
# 1                 20
# 2                 21
# 3                 19
# 4                 19
#
#   What is your preferred music genre to listen to at parties?   \
# 0                                 Hip Hop & R&B, Pop
# 1                     Hip Hop & R&B, Electronic, Pop
# 2                     Hip Hop & R&B, Electronic, Pop
# 3                     Hip Hop & R&B, Electronic, Pop
# 4                                 Hip Hop & R&B, Pop
#
#   What are your top 5 songs before going out (this can be on your own or with others) (e.g., pregame, getting ready, etc.)? \n\n*Please specify song title and artist(s)!*  \
# 0  Rhianna - Where Have You Been, Bad Bunny - EoO...
# 1  Melancholy Hill, any Rocco song, Love Me Not, ...
# 2  any spanish reggaeton song or early 2000s pop ...
# 3  time to pretend mgmt, spin about you drake, lo...
# 4  DtMF by bad bunny, luther by kendrick and sza,...
#
#   What do you like about the parties you have gone to so far? (music, environment, loudness, etc. )   \
# 0  I liked the music they've had, and the convers...
# 1                     The people there, the loudness
# 2                    music, dancing, and environment
# 3            music, chalant people, welcoming crowd
# 4  I like the music and just seeing the general h...
#
#   What don't you like about parties? (music, environment, loudness, etc. )   \
# 0  I don't like when others excessively use subst...
# 1  The environment, how parties always happe so late
# 2  If the music is bad, awkward people or not eno...
# 3                            rude nonchalant people
# 4  I don't typically like the drinking environmen...
#
#    On a scale of 1-5, how likely are you to pregame before a party/gathering?\n(1 = very unlikely, 5 = very likely)  \
# 0                                                  4
# 1                                                  2
# 2                                                  5
# 3                                                  2
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   On a scale of 1-5, how likely are you to sing along to a song at a party sober?\n(1 = very unlikely, 5 = very likely)  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  5
#
#   When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?  \
# 0                  singing, ambience with good vibes
# 1  Something to pump up or fill in the lack of en...
# 2                              dancing and ambience
# 3                             reminiscing & singing
# 4  I think having a playlist that is fun, nostalg...
#
#                            Why do you go to parties?  \
# 0           To socialize with my friends and dance.
# 1  For free drinks foods or with my friends or to...
# 2  FOMO, friends are going and to take a break fr...
# 3                        make memories & to have fun
# 4  Just to be with friends who are there and for ...
#
#    What is/are your ethnicity/ies? What is/are your nationality/ ies?  \
# 0                           Latino                   Meixcan-American
# 1                       Vietnamese                           American
# 2                        Hispanic                           American
# 3              Chinese/Vietnamese                           American
# 4                       Vietnamese                           American
#
#   On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?\n(1 = very unlikely, 5 = very likely)  \
# 0                                                  2
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#   On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#   Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)  \
# 0                                  admontan@ucsd.edu
# 1                                                 No
# 2                                                N/a
# 3                                                 no
# 4                                       No thank you
#
#    Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!\n\n*Please specify song title and artist(s)!*  \
# 0  Bad Bunny - Baile Inolvidable, Karol G - Si An...
# 1  Any Daniel ceasar song, Melancholy Hill, Every...
# 2  never hosted before but would put Spanish regg...
# 3  lady killers, 3 strikes, girlfriend heavy weig...
# 4  I like all the stars by kendrick and sza, titi...
#
#    Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)
# 0  Yes I have. While I feel more shy sometimes, i...
# 1                                Yes, I laughed more
# 2  Yes, I tried drinking but I ended up throwing ...
# 3  yes it was chill everybody was already in a ha...
# 4                                                NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Renaming Columns

# %% [markdown]
# The column names are pretty long so I'll reformat them to be easier to call on and stuff:

# %%
# getting column names again after dropping columns and also seeing how many questions there are in the survey

i=0
for col in survey_df.columns:
    print(f"#{i}: {col}")
    i += 1

survey_df.columns.to_list()
# Out:
# #0: Timestamp
# #1: What is your gender identity?
# #2: What is your preferred music genre? (on a daily basis)
# #3: On a scale of 1-5, how introverted are you?
# (1 = introverted, 5 = extroverted)
# #4: How old are you?
# #5: What is your preferred music genre to listen to at parties?
# #6: What are your top 5 songs before going out (this can be on your own or with others) (e.g., pregame, getting ready, etc.)?
#
# *Please specify song title and artist(s)!*
# #7: What do you like about the parties you have gone to so far? (music, environment, loudness, etc. )
# #8: What don't you like about parties? (music, environment, loudness, etc. )
# #9: On a scale of 1-5, how likely are you to pregame before a party/gathering?
# (1 = very unlikely, 5 = very likely)
# #10: How many times have you gone to a gathering in the last 2 months?
# #11: What emotions do you feel when listening to these top 5 songs?
# #12: On a scale of 1-5, how likely are you to come up to a stranger at a party sober?
# (1 = very unlikely, 5 = very likely)
# #13: On a scale of 1-5, how likely are you to sing along to a song at a party sober?
# (1 = very unlikely, 5 = very likely)
# #14: When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?
# #15: Why do you go to parties?
# #16: What is/are your ethnicity/ies?
# #17: What is/are your nationality/ ies?
# #18: On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?
# (1 = very unlikely, 5 = very likely)
# #19: On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?
# #20: Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)
# #21: Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!
#
# *Please specify song title and artist(s)!*
# #22: Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)
# ['Timestamp',
#  'What is your gender identity? ',
#  'What is your preferred music genre? (on a daily basis) ',
#  'On a scale of 1-5, how introverted are you?\n(1 = introverted, 5 = extroverted)',
#  'How old are you? ',
#  'What is your preferred music genre to listen to at parties? ',
#  'What are your top 5 songs before going out (this can be on your own or with others) (e.g., pregame, getting ready, etc.)? \n\n*Please specify song title and artist(s)!*',
#  'What do you like about the parties you have gone to so far? (music, environment, loudness, etc. ) ',
#  "What don't you like about parties? (music, environment, loudness, etc. ) ",
#  'On a scale of 1-5, how likely are you to pregame before a party/gathering?\n(1 = very unlikely, 5 = very likely)',
#  'How many times have you gone to a gathering in the last 2 months?',
#  'What emotions do you feel when listening to these top 5 songs?',
#  'On a scale of 1-5, how likely are you to come up to a stranger at a party sober? \n(1 = very unlikely, 5 = very likely)',
#  'On a scale of 1-5, how likely are you to sing along to a song at a party sober?\n(1 = very unlikely, 5 = very likely)',
#  'When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?',
#  'Why do you go to parties?',
#  'What is/are your ethnicity/ies?',
#  'What is/are your nationality/ ies?',
#  "On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?\n(1 = very unlikely, 5 = very likely)",
#  "On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?",
#  'Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)',
#  'Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!\n\n*Please specify song title and artist(s)!*',
#  'Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)']

# %%
# change column names to be more descriptive and easier to work with
survey_df = survey_df.rename(columns={

    # Demographics
    'What is your gender identity? ': 'gender',
    'How old are you? ': 'age',
    'What is/are your ethnicity/ies?': 'ethnicity',
    'What is/are your nationality/ ies?': 'nationality',
    'On a scale of 1-5, how introverted are you?\n(1 = introverted, 5 = extroverted)': 'introversion_score',

    # Music Preferences
    'What is your preferred music genre? (on a daily basis) ': 'preferred_genre_daily', 
    'What is your preferred music genre to listen to at parties? ': 'preferred_genre_parties',
    'What are your top 5 songs before going out (this can be on your own or with others) (e.g., pregame, getting ready, etc.)? \n\n*Please specify song title and artist(s)!*': 'top_5_songs_before_going_out',
    'What emotions do you feel when listening to these top 5 songs?': 'emotions_top_5_songs',
    'Top 5 songs when hosting a party? If you have never hosted a party, please answer what you would put in your playlist!\n\n*Please specify song title and artist(s)!*': 'top_5_songs_when_hosting_party',    
    'When you curate your party music playlist (even hypothetically), what is your intent for the party? For the people?': 'party_playlist_intent',

    # Party Experiences
    'Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.)': 'party_experience_sober',
    'On a scale of 1-5, how likely are you to pregame before a party/gathering?\n(1 = very unlikely, 5 = very likely)': 'pregame_likelihood_score',
    'How many times have you gone to a gathering in the last 2 months?': 'times_in_last_2_months',
    'On a scale of 1-5, how likely are you to come up to a stranger at a party sober? \n(1 = very unlikely, 5 = very likely)': 'likelihood_approach_stranger_score',
    'On a scale of 1-5, how likely are you to sing along to a song at a party sober?\n(1 = very unlikely, 5 = very likely)': 'likelihood_sing_along_score',
    "On a scale of 1-5, how likely are you are you to start a conversation with someone you don't know at a party with NO music sober?\n(1 = very unlikely, 5 = very likely)": 'likelihood_conversation_no_music_score',
    "On a scale of 1-5, how likely are you to start a conversation with someone you don't know at a house party with LOUD music sober?": 'likelihood_conversation_loud_music_score',
    'Why do you go to parties?': 'reason_for_going_to_parties',
    'What do you like about the parties you have gone to so far? (music, environment, loudness, etc. ) ': 'party_likes',
    "What don't you like about parties? (music, environment, loudness, etc. ) ": 'parties_dislikes',

    # Interview Participation
    'Are you willing to participate in a short (anonymous) interview about your party experiences? (If yes, input your email)': 'interview_participation_email',
})

#let's look at the dataframe again after renaming the columns:
survey_df.head()
# Out:
#             Timestamp   gender            preferred_genre_daily  \
# 0  2/25/2026 12:10:43     Male                  Electronic, Pop
# 1  2/25/2026 12:19:46   Female                    Hip Hop & R&B
# 2  2/25/2026 12:21:41  Female                Hip Hop & R&B, Pop
# 3  2/25/2026 12:32:51  female                Hip Hop & R&B, Pop
# 4  2/25/2026 12:38:44   Female  Metal/ Rock, Hip Hop & R&B, Pop
#
#    introversion_score  age         preferred_genre_parties  \
# 0                   3   23              Hip Hop & R&B, Pop
# 1                   2   20  Hip Hop & R&B, Electronic, Pop
# 2                   4   21  Hip Hop & R&B, Electronic, Pop
# 3                   3   19  Hip Hop & R&B, Electronic, Pop
# 4                   2   19              Hip Hop & R&B, Pop
#
#                         top_5_songs_before_going_out  \
# 0  Rhianna - Where Have You Been, Bad Bunny - EoO...
# 1  Melancholy Hill, any Rocco song, Love Me Not, ...
# 2  any spanish reggaeton song or early 2000s pop ...
# 3  time to pretend mgmt, spin about you drake, lo...
# 4  DtMF by bad bunny, luther by kendrick and sza,...
#
#                                          party_likes  \
# 0  I liked the music they've had, and the convers...
# 1                     The people there, the loudness
# 2                    music, dancing, and environment
# 3            music, chalant people, welcoming crowd
# 4  I like the music and just seeing the general h...
#
#                                     parties_dislikes  \
# 0  I don't like when others excessively use subst...
# 1  The environment, how parties always happe so late
# 2  If the music is bad, awkward people or not eno...
# 3                            rude nonchalant people
# 4  I don't typically like the drinking environmen...
#
#    pregame_likelihood_score  ... likelihood_sing_along_score  \
# 0                         4  ...                           5
# 1                         2  ...                           5
# 2                         5  ...                           3
# 3                         2  ...                           1
# 4                         1  ...                           5
#
#                                party_playlist_intent  \
# 0                  singing, ambience with good vibes
# 1  Something to pump up or fill in the lack of en...
# 2                              dancing and ambience
# 3                             reminiscing & singing
# 4  I think having a playlist that is fun, nostalg...
#
#                          reason_for_going_to_parties            ethnicity  \
# 0           To socialize with my friends and dance.                Latino
# 1  For free drinks foods or with my friends or to...           Vietnamese
# 2  FOMO, friends are going and to take a break fr...            Hispanic
# 3                        make memories & to have fun  Chinese/Vietnamese
# 4  Just to be with friends who are there and for ...           Vietnamese
#
#         nationality likelihood_conversation_no_music_score  \
# 0  Meixcan-American                                      2
# 1          American                                      1
# 2         American                                       2
# 3         American                                       4
# 4          American                                      3
#
#   likelihood_conversation_loud_music_score interview_participation_email  \
# 0                                        3             admontan@ucsd.edu
# 1                                        3                            No
# 2                                        3                           N/a
# 3                                        2                            no
# 4                                        2                  No thank you
#
#                       top_5_songs_when_hosting_party  \
# 0  Bad Bunny - Baile Inolvidable, Karol G - Si An...
# 1  Any Daniel ceasar song, Melancholy Hill, Every...
# 2  never hosted before but would put Spanish regg...
# 3  lady killers, 3 strikes, girlfriend heavy weig...
# 4  I like all the stars by kendrick and sza, titi...
#
#                               party_experience_sober
# 0  Yes I have. While I feel more shy sometimes, i...
# 1                                Yes, I laughed more
# 2  Yes, I tried drinking but I ended up throwing ...
# 3  yes it was chill everybody was already in a ha...
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
# and let's look at the column names again to make sure they are correct:
survey_df.columns.to_list(), len(survey_df.columns)
# Out:
# (['Timestamp',
#   'gender',
#   'preferred_genre_daily',
#   'introversion_score',
#   'age',
#   'preferred_genre_parties',
#   'top_5_songs_before_going_out',
#   'party_likes',
#   'parties_dislikes',
#   'pregame_likelihood_score',
#   'times_in_last_2_months',
#   'emotions_top_5_songs',
#   'likelihood_approach_stranger_score',
#   'likelihood_sing_along_score',
#   'party_playlist_intent',
#   'reason_for_going_to_parties',
#   'ethnicity',
#   'nationality',
#   'likelihood_conversation_no_music_score',
#   'likelihood_conversation_loud_music_score',
#   'interview_participation_email',
#   'top_5_songs_when_hosting_party',
#   'party_experience_sober'],
#  23)

# %% [markdown]
# ## Cleaning Survey Data
#
# Now we wanna make sure our data is pretty clean, meaning there's no substantial amounts of missing values and see if responses are what they should be. To be honest, there shouldn't be many missing values since most questions are required (other than "Have you ever gone to a party sober? (if yes, explain your experience with it: what you liked what surprised you vs. going to a party not sober, etc.) and something else I think?)

# %%
# checking missing values in each column
survey_df.isnull().sum()
# Out:
# Timestamp                                   0
# gender                                      0
# preferred_genre_daily                       0
# introversion_score                          0
# age                                         0
# preferred_genre_parties                     0
# top_5_songs_before_going_out                0
# party_likes                                 0
# parties_dislikes                            0
# pregame_likelihood_score                    0
# times_in_last_2_months                      0
# emotions_top_5_songs                        0
# likelihood_approach_stranger_score          0
# likelihood_sing_along_score                 0
# party_playlist_intent                       0
# reason_for_going_to_parties                 0
# ethnicity                                   0
# nationality                                 0
# likelihood_conversation_no_music_score      0
# likelihood_conversation_loud_music_score    0
# interview_participation_email               5
# top_5_songs_when_hosting_party              1
# party_experience_sober                      4
# dtype: int64

# %%
# only 3 columns have missing values, let's look at them:
survey_df[['party_experience_sober', 'top_5_songs_when_hosting_party', 'interview_participation_email']]
# Out:
#                                party_experience_sober  \
# 0   Yes I have. While I feel more shy sometimes, i...
# 1                                 Yes, I laughed more
# 2   Yes, I tried drinking but I ended up throwing ...
# 3   yes it was chill everybody was already in a ha...
# 4                                                 NaN
# 5   yes; if the music is good, i tend to have a go...
# 6    i enjoyed witnessing everyone that was not sober
# 7                                                 NaN
# 8   Yes. Honestly, I prefer to be sober at parties...
# 9   I have only been sober at parties, and it can ...
# 10  I was more calm and not as willing to talk to ...
# 11                                                 No
# 12                                               nope
# 13  yes, it can be just as fun with the right peop...
# 14                                                NaN
# 15                                                 No
# 16  Yes it out but I was a little bored  when I we...
# 17                                                NaN
# 18  Yes, well, it’s exciting  because I really enj...
# 19  I don’t really like to drink and I would say I...
# 20                                                no
# 21  I liked that I was able to have a good time wi...
# 22                                                 no
# 23  Yes, I liked how upbeat the music was and how ...
# 24  It was kinda boring when I was sober because m...
# 25  Yes, it was honestly just as fun. I went with ...
# 26  yes, but going to a party sober makes the expe...
# 27  Yes, I like being more aware but when I’m not ...
# 28  yes, it was a bit scary because i am socially ...
# 29  Yes. It was nice getting to know people and ha...
#
#                        top_5_songs_when_hosting_party  \
# 0   Bad Bunny - Baile Inolvidable, Karol G - Si An...
# 1   Any Daniel ceasar song, Melancholy Hill, Every...
# 2   never hosted before but would put Spanish regg...
# 3   lady killers, 3 strikes, girlfriend heavy weig...
# 4   I like all the stars by kendrick and sza, titi...
# 5   talk talk - charli xcx, stateside + bladee - p...
# 6   latch- disclosure, doses&mimosas- cherub, savi...
# 7                                      I have no idea
# 8   All I Ever Asked by Rachel Chinouriri, Love is...
# 9   deep in it by berlioz, breezy (inst.) by rolle...
# 10  Tiene espinas el rosal, love generation, inolv...
# 11  Gasolina, no hands, party rock anthem, clarity...
# 12                                       i don’t host
# 13  trap queen-fetty wap, roses- chainsmokers, cla...
# 14                                                NaN
# 15  1) Clarity by Zedd, 2) Smokin Out The Window b...
# 16  F.n.f -gorilla, gas pedal - sage the Gemini , ...
# 17  We are the people by empire of the sun, My lov...
# 18  1.- Don’t stop the party, 2.- perdóname -facto...
# 19             Any drake, A$AP, Spanish music,Rihanna
# 20  throw sum mo- swae lee, we found love- rihanna...
# 21  El Liston De Tu Pelo(Los Angeles Azules), 20 R...
# 22  I don't host parties, but definitely heavy bea...
# 23  So Easy by Olivia Dean, NEW DROP by Don Tolive...
# 24  Gasolina (daddy yankee), Party in the USA(Mile...
# 25  Clarity zedd, meet me halfway black eyed peas,...
# 26  Club Classics (charli xcx), Stay the night (Ze...
# 27  Clarity - Zedd, Inténtalo- 3BallMTY, Porque El...
# 28  fw me (dirty) - knock2 & rhea raj, i got a que...
# 29  -MyWay (Fetty Wap), Maneater (Nelly Furtado), ...
#
#                         interview_participation_email
# 0                                   admontan@ucsd.edu
# 1                                                  No
# 2                                                 N/a
# 3                                                  no
# 4                                        No thank you
# 5                               suree; mjsok@ucsd.edu
# 6                                          no sorry😓😓
# 7                            I don't have experience
# 8                           brittneydnguyen@gmail.com
# 9                     santiago.valdivia1111@gmail.com
# 10                                                 No
# 11                                                 No
# 12                                                NaN
# 13                         yur @esk01012006@gmail.com
# 14                                                NaN
# 15                               Yes: t9doan@ucsd.edu
# 16                                 J4blanco@ucsd.edu
# 17                                      No thank you
# 18  Yes, salmup26@gmail.com or i24221220.02@puebla...
# 19                                        No thank u!
# 20                          yes ivanatram33@gmail.com
# 21                                                NaN
# 22                                                 no
# 23                                                NaN
# 24                                                NaN
# 25                                            I’m ok
# 26                                      no thank you!
# 27                            epizarroalfaro@ucsd.esu
# 28                          natnatnatalie18@gmail.com
# 29                               YES (khyun@ucsd.edu)

# %%
# weird, row 14 yas NaN for the 3 rows, let's look at the original dataframe to see if there is something wrong with the data in that row:
survey_df.iloc[14]
# Out:
# Timestamp                                                                  2/25/2026 15:23:33
# gender                                                                                 Female
# preferred_genre_daily                                                      Hip Hop & R&B, Pop
# introversion_score                                                                          3
# age                                                                                        20
# preferred_genre_parties                                        Hip Hop & R&B, Electronic, Pop
# top_5_songs_before_going_out                        No Hands, OMG, Blackout, Blame It, Issues
# party_likes                                      Good music, good drinks, good vibes & people
# parties_dislikes                                                 Vibes that are not welcoming
# pregame_likelihood_score                                                                    4
# times_in_last_2_months                                                                      2
# emotions_top_5_songs                                                Very hyped up and excited
# likelihood_approach_stranger_score                                                          2
# likelihood_sing_along_score                                                                 2
# party_playlist_intent                                         Depends on the vibe of the look
# reason_for_going_to_parties                 For fun and to socialize with new people/curre...
# ethnicity                                                                         Vietnamese
# nationality                                                                   Asian American
# likelihood_conversation_no_music_score                                                      2
# likelihood_conversation_loud_music_score                                                    2
# interview_participation_email                                                             NaN
# top_5_songs_when_hosting_party                                                            NaN
# party_experience_sober                                                                    NaN
# Name: 14, dtype: object

# %% [markdown]
# honeslty idk why or how those values are missing for that individual, especially since `top_5_songs_when_hosting_party` is a required response field but maybe the survey had changed somehow since she took it? Anyway I think the mising values we have aren't a big deal so I'll go ahead and keep it as is. now we wanna tidy up the data!

# %% [markdown]
# ### Cleaning responses
# Ok so clearly people don't know what nationality vs ethnicity is so we're gonna have to clean that up a bit or change it to race I honestly don't know lol.
#
# Also for the `gender` data, people also clearly don't know the difference b/w sex and gender lol. Most ppl wrote 'female' or 'male' so maybe we can clean it up by just standardizing the responses to sex? but there were some entries like 'gender fluid (fem) and for some reason 'Straight' bruhhh'

# %% [markdown]
# ## Tidying Survey Data

# %% [markdown]
# Now we wanna make sure our data is nice and tidy (1 observation per row, 1 variable per column, and 1 value per cell). This is gonna be tough because we have some columns that are open-ended questions, notably the "top 5" answers which include 5 songs per response (usually, there's some people who don't even write the 5 songs + artists out ToT).

# %%
# checking data types
survey_df.dtypes
# Out:
# Timestamp                                   object
# gender                                      object
# preferred_genre_daily                       object
# introversion_score                           int64
# age                                          int64
# preferred_genre_parties                     object
# top_5_songs_before_going_out                object
# party_likes                                 object
# parties_dislikes                            object
# pregame_likelihood_score                     int64
# times_in_last_2_months                      object
# emotions_top_5_songs                        object
# likelihood_approach_stranger_score           int64
# likelihood_sing_along_score                  int64
# party_playlist_intent                       object
# reason_for_going_to_parties                 object
# ethnicity                                   object
# nationality                                 object
# likelihood_conversation_no_music_score       int64
# likelihood_conversation_loud_music_score     int64
# interview_participation_email               object
# top_5_songs_when_hosting_party              object
# party_experience_sober                      object
# dtype: object

# %% [markdown]
# # 2) Wrangling

# %% [markdown]
# # 3) EDA - what patterns do we see?
